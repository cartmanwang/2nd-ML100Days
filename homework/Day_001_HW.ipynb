# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_predict):
    """
    請完成這個 Function 後往下執行
    """
    return sum((y - y_predict)**2) / len(y)

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.figure(figsize=(8,6))
plt.plot(x_lin, y, 'b.', label = 'data points')

plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# <p style="font-family: Arial; font-size:1.50em;color:mediumblue; font-style:bold"><br>
# # 作業3<br></p>

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 232.692
# The Mean absolute error is 11.619

# %% [markdown]
# <p style="font-family: Arial; font-size:1.50em;color:mediumblue; font-style:bold"><br>
# # 作業1<br></p>

# %% [markdown]
# Dataset: **Credit Card Fraud Detection**
#
# 1. 透過這份資料的分析運用可協助持卡人與信用卡機構降低因盜刷(詐欺)所帶來的損失
# 2. 由 Worldline 及 Machine Learning Group of ULB(Université Libre de Bruxelles) 共同收集而來，2013年9月某兩天的信用卡刷卡紀錄
# 3. 結構化資料，但大多數欄位皆已經過加密處理，難以辨別欄位名稱及意義
# 4. 由於實際詐欺案件的比例只有極低的0.17%，資料提供者建議使用 Area Under the Precision-Recall Curve (AUPRC) 進行評估

# %% [markdown]
# <p style="font-family: Arial; font-size:1.50em;color:mediumblue; font-style:bold"><br>
# # 作業2<br></p>

# %% [markdown]
# 1. 如果在都會區，跳表距離由250m/次調整為225m/次，但起跳金額由75元調降到70元是否能提升整體營業額?
# 2. 分析歷史載客資料以瞭解都會區乘客的搭車習慣或趨勢，並參考過去價格調整時對業績的影響來判斷顧客對金額變動的敏感度，必要時也可透過問券
# 3. 結構化資料
# 4. 調整後對營業額的影響: MSE
